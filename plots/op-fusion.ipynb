# %%
# %matplotlib inline
import sys
sys.path.append('../../utils')
import utils as u
import math

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import MultipleLocator
from random import randint
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.backends.backend_pdf import PdfPages

from palettable.colorbrewer.sequential import YlGnBu_5

# %%
#Loading data

color=['#edf8b1','#7fcdbb','#225ea8']
df = pd.read_csv('data/productivity.csv')

fig, ax = plt.subplots(figsize=(12, 5))
# plt.xticks(rotation=90)

# plt.xlim(0, 4.2)
# Put limit on Y axis
# plt.ylim(0, 1)


N = len(df['year'])
ind = np.arange(N)
width = 0.4


# Instantiating the X bar
# cbars = ax.bar(ind+0.8, df['mul'].values.tolist(), \
#                width, ecolor='k', color=u.getcolor(3), edgecolor='k');
#cbars = ax.bar(ind+0.8, df['data'].values.tolist(), width, color=YlGnBu_5.hex_colors[4])
cbars = ax.bar(ind+0.6, df['data'].values.tolist(), width, color=color[2], edgecolor='k')

# ax.text(1, -0.41, "Banking + Fusion + Tile(4)", fontsize=18, rotation=0)


# Writing text on top of the bars
# c = 0
# ll = df['performance'].values.tolist()
# for t in df['data']:
#     if(int(t) > 50):
#         ax.text(c+0.65, 62+0.2, str(int(t)), fontsize=18, rotation=0)
#     else:
#         ax.text(c+0.65, ll[c]+0.2, str(int(t)), fontsize=18, rotation=0)
#     c += 1

# Set X label values
ax.set_ylabel('Normalized Exe.',fontsize=38, color='black')
ax.set_xticks(ind+0.6);

# Put the labels from 'app' coulmn
ax.set_xticklabels(u.rename(df['app']))
ax.set_facecolor('whitesmoke')

plt.grid(linestyle='--', which='major', color='darkgray')
plt.gca().xaxis.grid(False)
plt.gca().yaxis.grid(True, color='black')

plt.tick_params( axis='x', which='both', bottom=False, top=False, colors='black', labelsize=24)
plt.tick_params( axis='y', which='both', right=False, colors='black', labelsize=32 )
plt.tick_params(axis='both', which='major', direction='in', 
                length=6, width=3,color='black')

plt.yticks(np.arange(0, 1.1, 0.2))
ax.text(3.1, 1.05, "Baseline IR = 1", fontsize=24, rotation=0)


ax.set_axisbelow(True)
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['left'].set_color('gray')

# Saving the plot
fig.savefig('op-fusion.pdf',
            facecolor=fig.get_facecolor(), bbox_inches='tight')
